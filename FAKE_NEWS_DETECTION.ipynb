# %%
#importing all required modules
import numpy as np
import pandas as pd
import json
import csv
import random

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers

import pprint
import tensorflow.compat.v1 as tf
from tensorflow.python.framework import ops
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
tf.disable_eager_execution()

# Reading the data
data = pd.read_csv("/content/drive/MyDrive/colab data/news.csv")
data.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#display top 5 rows
data = data.drop(["Unnamed: 0"], axis=1)
data.head(5)
# Out:
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        Kerry to go to Paris in gesture of sympathy
# 3  Bernie supporters on Twitter erupt in anger ag...
# 4   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
# encoding the labels
le = preprocessing.LabelEncoder()
le.fit(data['label'])
data['label'] = le.transform(data['label'])

# %%
embedding_dim = 50
max_length = 54
trunc_type = 'post'
padding_type = 'post'
oov_tok = "<OOV>"
training_size = 3000
test_portion = .1

# %%
title = []
text = []
labels = []
for x in range(training_size):
	title.append(data['title'][x])
	text.append(data['text'][x])
	labels.append(data['label'][x])

# %%
#tokenization
tokenizer1 = Tokenizer()
tokenizer1.fit_on_texts(title)
word_index1 = tokenizer1.word_index
vocab_size1 = len(word_index1)
sequences1 = tokenizer1.texts_to_sequences(title)
padded1 = pad_sequences(
	sequences1, padding=padding_type, truncating=trunc_type)
split = int(test_portion * training_size)
training_sequences1 = padded1[split:training_size]
test_sequences1 = padded1[0:split]
test_labels = labels[0:split]
training_labels = labels[split:training_size]

# %%
embeddings_index = {}
with open('/content/drive/MyDrive/colab data/glove.6B.50d.txt') as f:
	for line in f:
		values = line.split()
		word = values[0]
		coefs = np.asarray(values[1:], dtype='float32')
		embeddings_index[word] = coefs

# Generating embeddings
embeddings_matrix = np.zeros((vocab_size1+1, embedding_dim))
for word, i in word_index1.items():
	embedding_vector = embeddings_index.get(word)
	if embedding_vector is not None:
		embeddings_matrix[i] = embedding_vector

# %%
model = tf.keras.Sequential([
	tf.keras.layers.Embedding(vocab_size1+1, embedding_dim,
							input_length=max_length, weights=[
								embeddings_matrix],
							trainable=False),
	tf.keras.layers.Dropout(0.2),
	tf.keras.layers.Conv1D(64, 5, activation='relu'),
	tf.keras.layers.MaxPooling1D(pool_size=4),
	tf.keras.layers.LSTM(64),
	tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',
			optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 54, 50)            377600
#
#  dropout (Dropout)           (None, 54, 50)            0
#
#  conv1d (Conv1D)             (None, 50, 64)            16064
#
#  max_pooling1d (MaxPooling1  (None, 12, 64)            0
#  D)
#
#  lstm (LSTM)                 (None, 64)                33024
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 426753 (1.63 MB)
# Trainable params: 49153 (192.00 KB)
# Non-trainable params: 377600 (1.44 MB)
# _________________________________________________________________

# %%
#Run 50 epochs
num_epochs = 50

training_padded = np.array(training_sequences1)
training_labels = np.array(training_labels)
testing_padded = np.array(test_sequences1)
testing_labels = np.array(test_labels)

history = model.fit(training_padded, training_labels,
					epochs=num_epochs,
					validation_data=(testing_padded,
									testing_labels),
					verbose=2)
# Out:
# Train on 2700 samples, validate on 300 samples
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2700/2700 - 4s - loss: 0.6533 - accuracy: 0.5963 - val_loss: 0.5751 - val_accuracy: 0.6633 - 4s/epoch - 2ms/sample
# Epoch 2/50
# 2700/2700 - 2s - loss: 0.5792 - accuracy: 0.7030 - val_loss: 0.5289 - val_accuracy: 0.7267 - 2s/epoch - 768us/sample
# Epoch 3/50
# 2700/2700 - 2s - loss: 0.5357 - accuracy: 0.7252 - val_loss: 0.5431 - val_accuracy: 0.7000 - 2s/epoch - 625us/sample
# Epoch 4/50
# 2700/2700 - 2s - loss: 0.4999 - accuracy: 0.7604 - val_loss: 0.5103 - val_accuracy: 0.7533 - 2s/epoch - 632us/sample
# Epoch 5/50
# 2700/2700 - 2s - loss: 0.4484 - accuracy: 0.7926 - val_loss: 0.4946 - val_accuracy: 0.7633 - 2s/epoch - 630us/sample
# Epoch 6/50
# 2700/2700 - 2s - loss: 0.4040 - accuracy: 0.8244 - val_loss: 0.4843 - val_accuracy: 0.7467 - 2s/epoch - 618us/sample
# Epoch 7/50
# 2700/2700 - 2s - loss: 0.3946 - accuracy: 0.8267 - val_loss: 0.4841 - val_accuracy: 0.7700 - 2s/epoch - 623us/sample
# Epoch 8/50
# 2700/2700 - 3s - loss: 0.3171 - accuracy: 0.8644 - val_loss: 0.5262 - val_accuracy: 0.7533 - 3s/epoch - 1ms/sample
# Epoch 9/50
# 2700/2700 - 2s - loss: 0.3030 - accuracy: 0.8681 - val_loss: 0.5802 - val_accuracy: 0.7167 - 2s/epoch - 867us/sample
# Epoch 10/50
# 2700/2700 - 2s - loss: 0.2501 - accuracy: 0.8996 - val_loss: 0.5496 - val_accuracy: 0.7400 - 2s/epoch - 633us/sample
# Epoch 11/50
# 2700/2700 - 2s - loss: 0.2295 - accuracy: 0.9041 - val_loss: 0.6015 - val_accuracy: 0.7500 - 2s/epoch - 618us/sample
# Epoch 12/50
# 2700/2700 - 2s - loss: 0.2025 - accuracy: 0.9144 - val_loss: 0.6677 - val_accuracy: 0.7400 - 2s/epoch - 632us/sample
# Epoch 13/50
# 2700/2700 - 2s - loss: 0.1825 - accuracy: 0.9293 - val_loss: 0.6180 - val_accuracy: 0.7633 - 2s/epoch - 630us/sample
# Epoch 14/50
# 2700/2700 - 2s - loss: 0.1734 - accuracy: 0.9315 - val_loss: 0.6402 - val_accuracy: 0.7533 - 2s/epoch - 637us/sample
# Epoch 15/50
# 2700/2700 - 3s - loss: 0.1775 - accuracy: 0.9367 - val_loss: 0.6638 - val_accuracy: 0.7233 - 3s/epoch - 978us/sample
# Epoch 16/50
# 2700/2700 - 3s - loss: 0.1947 - accuracy: 0.9219 - val_loss: 0.6332 - val_accuracy: 0.7500 - 3s/epoch - 967us/sample
# Epoch 17/50
# 2700/2700 - 2s - loss: 0.1630 - accuracy: 0.9407 - val_loss: 0.7403 - val_accuracy: 0.7133 - 2s/epoch - 626us/sample
# Epoch 18/50
# 2700/2700 - 2s - loss: 0.1393 - accuracy: 0.9430 - val_loss: 0.7267 - val_accuracy: 0.7433 - 2s/epoch - 642us/sample
# Epoch 19/50
# 2700/2700 - 2s - loss: 0.1249 - accuracy: 0.9548 - val_loss: 0.8000 - val_accuracy: 0.7600 - 2s/epoch - 623us/sample
# Epoch 20/50
# 2700/2700 - 2s - loss: 0.1323 - accuracy: 0.9500 - val_loss: 0.7325 - val_accuracy: 0.7200 - 2s/epoch - 631us/sample
# Epoch 21/50
# 2700/2700 - 2s - loss: 0.1307 - accuracy: 0.9522 - val_loss: 0.8049 - val_accuracy: 0.7500 - 2s/epoch - 628us/sample
# Epoch 22/50
# 2700/2700 - 2s - loss: 0.1316 - accuracy: 0.9515 - val_loss: 0.7786 - val_accuracy: 0.7567 - 2s/epoch - 850us/sample
# Epoch 23/50
# 2700/2700 - 3s - loss: 0.1161 - accuracy: 0.9559 - val_loss: 0.7598 - val_accuracy: 0.7633 - 3s/epoch - 1ms/sample
# Epoch 24/50
# 2700/2700 - 2s - loss: 0.1100 - accuracy: 0.9578 - val_loss: 0.7209 - val_accuracy: 0.7667 - 2s/epoch - 633us/sample
# Epoch 25/50
# 2700/2700 - 2s - loss: 0.1277 - accuracy: 0.9511 - val_loss: 0.8645 - val_accuracy: 0.7433 - 2s/epoch - 632us/sample
# Epoch 26/50
# 2700/2700 - 2s - loss: 0.1151 - accuracy: 0.9556 - val_loss: 0.8642 - val_accuracy: 0.7300 - 2s/epoch - 614us/sample
# Epoch 27/50
# 2700/2700 - 2s - loss: 0.0931 - accuracy: 0.9670 - val_loss: 0.8511 - val_accuracy: 0.7467 - 2s/epoch - 620us/sample
# Epoch 28/50
# 2700/2700 - 2s - loss: 0.0866 - accuracy: 0.9693 - val_loss: 0.7580 - val_accuracy: 0.7333 - 2s/epoch - 625us/sample
# Epoch 29/50
# 2700/2700 - 2s - loss: 0.1211 - accuracy: 0.9530 - val_loss: 0.7106 - val_accuracy: 0.7433 - 2s/epoch - 726us/sample
# Epoch 30/50
# 2700/2700 - 3s - loss: 0.0854 - accuracy: 0.9644 - val_loss: 0.7777 - val_accuracy: 0.7500 - 3s/epoch - 1ms/sample
# Epoch 31/50
# 2700/2700 - 2s - loss: 0.0919 - accuracy: 0.9622 - val_loss: 0.9208 - val_accuracy: 0.7400 - 2s/epoch - 703us/sample
# Epoch 32/50
# 2700/2700 - 2s - loss: 0.0896 - accuracy: 0.9707 - val_loss: 0.8617 - val_accuracy: 0.7533 - 2s/epoch - 610us/sample
# Epoch 33/50
# 2700/2700 - 2s - loss: 0.0743 - accuracy: 0.9711 - val_loss: 0.8732 - val_accuracy: 0.7467 - 2s/epoch - 620us/sample
# Epoch 34/50
# 2700/2700 - 2s - loss: 0.0737 - accuracy: 0.9730 - val_loss: 0.9499 - val_accuracy: 0.7533 - 2s/epoch - 625us/sample
# Epoch 35/50
# 2700/2700 - 2s - loss: 0.0858 - accuracy: 0.9681 - val_loss: 0.9968 - val_accuracy: 0.7433 - 2s/epoch - 624us/sample
# Epoch 36/50
# 2700/2700 - 2s - loss: 0.0747 - accuracy: 0.9693 - val_loss: 0.9437 - val_accuracy: 0.7400 - 2s/epoch - 629us/sample
# Epoch 37/50
# 2700/2700 - 3s - loss: 0.0798 - accuracy: 0.9704 - val_loss: 0.8937 - val_accuracy: 0.7800 - 3s/epoch - 1ms/sample
# Epoch 38/50
# 2700/2700 - 2s - loss: 0.0687 - accuracy: 0.9711 - val_loss: 0.8823 - val_accuracy: 0.7633 - 2s/epoch - 845us/sample
# Epoch 39/50
# 2700/2700 - 2s - loss: 0.0611 - accuracy: 0.9767 - val_loss: 1.0991 - val_accuracy: 0.7467 - 2s/epoch - 621us/sample
# Epoch 40/50
# 2700/2700 - 2s - loss: 0.0703 - accuracy: 0.9767 - val_loss: 0.9966 - val_accuracy: 0.7800 - 2s/epoch - 621us/sample
# Epoch 41/50
# 2700/2700 - 2s - loss: 0.0746 - accuracy: 0.9733 - val_loss: 1.0776 - val_accuracy: 0.7400 - 2s/epoch - 626us/sample
# Epoch 42/50
# 2700/2700 - 2s - loss: 0.0515 - accuracy: 0.9811 - val_loss: 1.0472 - val_accuracy: 0.7500 - 2s/epoch - 622us/sample
# Epoch 43/50
# 2700/2700 - 2s - loss: 0.0642 - accuracy: 0.9778 - val_loss: 0.9506 - val_accuracy: 0.7533 - 2s/epoch - 619us/sample
# Epoch 44/50
# 2700/2700 - 3s - loss: 0.0755 - accuracy: 0.9722 - val_loss: 1.0821 - val_accuracy: 0.7467 - 3s/epoch - 968us/sample
# Epoch 45/50
# 2700/2700 - 3s - loss: 0.0786 - accuracy: 0.9685 - val_loss: 0.7850 - val_accuracy: 0.7667 - 3s/epoch - 989us/sample
# Epoch 46/50
# 2700/2700 - 2s - loss: 0.0640 - accuracy: 0.9778 - val_loss: 0.9017 - val_accuracy: 0.7600 - 2s/epoch - 628us/sample
# Epoch 47/50
# 2700/2700 - 2s - loss: 0.0790 - accuracy: 0.9700 - val_loss: 0.9498 - val_accuracy: 0.7300 - 2s/epoch - 615us/sample
# Epoch 48/50
# 2700/2700 - 2s - loss: 0.0644 - accuracy: 0.9793 - val_loss: 0.8493 - val_accuracy: 0.7400 - 2s/epoch - 644us/sample
# Epoch 49/50
# 2700/2700 - 2s - loss: 0.0545 - accuracy: 0.9815 - val_loss: 1.1350 - val_accuracy: 0.7433 - 2s/epoch - 625us/sample
# Epoch 50/50
# 2700/2700 - 2s - loss: 0.0526 - accuracy: 0.9811 - val_loss: 0.9262 - val_accuracy: 0.7500 - 2s/epoch - 627us/sample

# %%
# sample text to check if fake or not
#giving fake news
X = """Click Here To Learn More About Alexandra's Personalized Essences Psychic Protection Click Here for More Information on Psychic Protection! Implant Removal Series Click here to listen to the IRP and SA/DNA Process Read The Testimonials Click Here To Read What Others Are Experiencing! Copyright Â© 2012 by Galactic Connection. All Rights Reserved.
Excerpts may be used, provided that full and clear credit is given to Alexandra Meadors and www.galacticconnection.com with appropriate and specific direction to the original content. Unauthorized use and/or duplication of any material on this website without express and written permission from its author and owner is strictly prohibited. Thank you.
Privacy Policy
By subscribing to GalacticConnection.com you acknowledge that your name and e-mail address will be added to our database. As with all other personal information, only working affiliates of GalacticConnection.com have access to this data. We do not give GalacticConnection.com addresses to outside companies, nor will we ever rent or sell your email address. Any e-mail you send to GalacticConnection.com is completely confidential. Therefore, we will not add your name to our e-mail list without your permission. Continue reading... Galactic Connection 2016 | Design & Development by AA at Superluminal Systems Sign Up forOur Newsletter
Join our newsletter to receive exclusive updates, interviews, discounts, and more. Join Us!"""

# detection
print("""
===================""")
sequences = tokenizer1.texts_to_sequences([X])[0]
sequences = pad_sequences([sequences], maxlen=54,
						padding=padding_type,
						truncating=trunc_type)
if(model.predict(sequences, verbose=0)[0][0] >= 0.5):
	print("This news is True")
else:
	print("This news is false")
# Out:
# ===================
# This news is false
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
# sample text to check if fake or not
#giving fake news
X = "Want FOX News First in your inbox every day? Sign up here."

# detection
print("""
===================""")
sequences = tokenizer1.texts_to_sequences([X])[0]
sequences = pad_sequences([sequences], maxlen=54,
						padding=padding_type,
						truncating=trunc_type)
if(model.predict(sequences, verbose=0)[0][0] >= 0.5):
	print("This news is True")
else:
	print("This news is false")
# Out:
# ===================
# This news is false

# %%
# sample text to check if fake or not
X = input("enter news : ")

# detection
print("""
===================""")
sequences = tokenizer1.texts_to_sequences([X])[0]
sequences = pad_sequences([sequences], maxlen=54,
						padding=padding_type,
						truncating=trunc_type)
if(model.predict(sequences, verbose=0)[0][0] >= 0.5):
	print("This news is True")
else:
	print("This news is false")
# Out:
# enter news : Muslims Start Chanting Allah On Plane, Flight Attendant Quickly Shuts Them Up Oct 29, 2016 Previous post
#
# ===================
# This news is false
